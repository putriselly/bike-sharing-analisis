# %% [markdown]
# # Proyek Analisis Data: Bike-sharing-dataset
# - **Nama:** putri selly
# - **Email:** putriselly01@student.upi.edu
# - **ID Dicoding:** PUTRI SELLY

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# **SMART Question** adalah sebuah framework untuk merumuskan pertanyaan secara terstruktur agar memeperoleh informasi yang mendalam.
#
# * **Spesific (Spesifik)**
#   * Pertanyaan harus jelas, fokus pada sebuah topik tertentu, dan tidak bermakna ganda. Hindari pertanyaan yang terlalu luas.
#     * Salah: Bagaimana cara meningkatkan penjualan?
#     * Benar: Faktor apa saja yang memengaruhi penurunan penjualan produk kategori elektronik di wilayah Jakarta selama kuartal terakhir?
# * **Measurable (Terukur)**
#   * Pertanyaan harus bisa dijawab dengan angka atau matrix yang konkret, harus tahu apa yang akan dihitung.
#     * Salah: Apakah pelanggan senang dengan layanan kita?
#     * Benar: Berapa skor rata-rata Customer Satisfaction untuk layanan purna jual bulan ini dibandingkan bulan lalu?
# * **Action-Oriented (Berorientasi Aksi)**
#   * Hasil dari pertanyaan harus bisa memberikan arahan untuk melakukan tindakan nyata. Jika pertanyaan terjawab, stakeholder harus tahu apa langkah selanjutnya.
#     * Salah: Mengapa orang suka berbelanja?
#     * Benar: Fitur apa pada aplikasi yang paling sering digunakan sebelum pengguna memutuskan untuk melakukan checkout?
# * **Relevant (Relevan)**
#   * Hasil dari pertanyaan harus sejalan dengan tujuan utama bisnis atau masalah yang sedang dihadapi.
#     * Salah: Menanyakan tentang stok gudang saat masalah utamanya adalah efektivitas kampanye media sosial.
#     * Benar: Apakah kampanye iklan di Instagram memberikan Return on Ad Spend (ROAS) yang lebih tinggi dibandingkan iklan di TikTok?
# * **Time-bound (Terikat Waktu)**
#   * Pertanyaan harus ada batasan waktu yang jelas agar analisis memiliki konteks yang tepat.
#     * Salah: Berapa banyak pengguna baru kita?
#     * Benar: Berapa tingkat pertumbuhan pengguna baru secara bulanan (Month-over-Month) sepanjang tahun 2025?

# %% [markdown]
# **Contoh pertanyaan bisnis yang memenuhi seluruh elemen SMART**
#
# ***"Faktor apa saja yang memengaruhi penurunan conversion rate pada pengguna aplikasi Android di wilayah Jabodetabek sebesar 5% selama periode Flash Sale Maret 2026?"***
#
# Keterangan:
#
# - **Specific**: Fokus pada "penurunan conversion rate" untuk "aplikasi Android" di "Jabodetabek". Bukan sekadar penjualan turun.
# - **Measurable**: Ada angka konkret yang ingin dianalisis, yaitu penurunan sebesar "5%".
# - **Action-Oriented**: Dengan mengetahui faktor penyebabnya misalnya bug pada versi Android tertentu atau kendala logistik di Jabodetabek, tim bisa langsung melakukan perbaikan teknis atau operasional.
# - **Relevant**: Penurunan konversi saat Flash Sale adalah masalah kritis bagi bisnis retail/e-commerce.
# - **Time-bound**: Dibatasi pada periode spesifik "Flash Sale Maret 2026".

# %% [markdown]
# - **Pertanyaan 1:** Apakah kondisi cuaca memengaruhi jumlah penyewaan sepeda?
# - **Pertanyaan 2:** Pada musim apa jumlah penyewaan sepeda paling tinggi, dan apakah musim memiliki pengaruh signifikan terhadap tingkat penyewaan?
# - ...

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# #### Load df ...

# %%
from google.colab import files
upload = files.upload()

df_day = pd.read_csv("day.csv")
df_hour = pd.read_csv("hour.csv")
# Out:
#      <input type="file" id="files-063a5e8e-16a0-47ee-9878-086d97d6b287" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-063a5e8e-16a0-47ee-9878-086d97d6b287">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ### Assessing Data

# %%
# day.csv
df_day.head()
df_day.info()
df_day.isna().sum()
print(df_day.duplicated().sum())
df_day.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB
# 0
# ...

# %%
# hour.csv
df_hour.head()
df_hour.info()
df_hour.isna().sum()
print(df_hour.duplicated().sum())
df_hour.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB
# 0
# ...

# %% [markdown]
# #### Identifying ... problem

# %% [markdown]
# **Steps to take:**
# - day_csv
# 1. Mengubah tipe data kolom dteday dari object menjadi datetime menggunakan pd.to_datetime().
# 2. Tidak diperlukan penanganan missing value karena tidak ditemukan data yang kosong.
# 3. Tidak diperlukan penghapusan data duplikat karena tidak ditemukan data yang duplikat.
# 4. Tidak diperlukan penanganan outlier/anomali karena statistik deskriptif tidak menunjukkan kejanggalan.
#
# - hour_csv
# 1. Mengubah tipe data kolom dteday dari object menjadi datetime menggunakan pd.to_datetime().
# 2. Tidak diperlukan penanganan missing value karena tidak ditemukan data yang kosong.
# 3. Tidak diperlukan penghapusan data duplikat karena tidak ditemukan data yang duplikat.
# 4. Tidak diperlukan penanganan outlier/anomali karena statistik deskriptif tidak menunjukkan kejanggalan.

# %% [markdown]
# **Insight:** (Opsional)
# - day_csv
# 1. berisi 731 data
# 2. tidak terdapat missing value
# 3. tidak terdapat duplikat
# 4. Tidak ditemukan kejanggalan yang terlihat dari statistik deskriptif pada variabel numerik.
# 5. terdapat sedikit kesalahan pada tipe data untuk kolom dteday, karena kolom ini berisi tanggal maka seharusnya bukan tipe data object melainkan bertipe datetime
#
# - hour_csv
# 1. terdapat 17379 data
# 2. terdapat sedikit kesalahan pada tipe data untuk kolom dteday, karena kolom ini berisi tanggal maka seharusnya bukan tipe data object melainkan bertipe datetime
# 3. tidak terdapat missing value
# 4. tidak terdapat duplikat
# 5. Tidak ditemukan kejanggalan yang terlihat dari statistik deskriptif pada variabel numerik.

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Fixing ... problem

# %%
df_day['dteday'] = pd.to_datetime(df_day['dteday'])
df_hour['dteday'] = pd.to_datetime(df_hour['dteday'])
df_day.info()
df_hour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.5 KB
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# **Insight:** (Opsional)
# - xxx
# - xxx

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
#day_csv
df_day.groupby('weathersit')['cnt'].agg(['mean', 'count']).sort_values(by='mean', ascending=False)
df_day.groupby('season')['cnt'].agg(['mean', 'count']).sort_values(by='mean', ascending=False)
# Out:
#                mean  count
# season
# 3       5644.303191    188
# 2       4992.331522    184
# 4       4728.162921    178
# 1       2604.132597    181

# %%
#hour_csv
df_hour.groupby('weathersit')['cnt'].agg(['mean', 'count']).sort_values(by='mean', ascending=False)
df_hour.groupby('season')['cnt'].agg(['mean', 'count']).sort_values(by='mean', ascending=False)
# Out:
#               mean  count
# season
# 3       236.016237   4496
# 2       208.344069   4409
# 4       198.868856   4232
# 1       111.114569   4242

# %% [markdown]
# **Insight:** (Opsional)
# - Pertanyaan 1: Pengaruh cuaca terhadap penyewaan sepeda
# 1. Rata-rata penyewaan tertinggi terjadi saat cuaca cerah (weathersit=1), yaitu 4.876/hari (day.csv) dan 204,87/jam (hour.csv).
# 2. Rata-rata penyewaan terus menurun seiring memburuknya cuaca, hingga terendah pada cuaca hujan/salju ringan (weathersit=3): 1.803/hari dan 111,58/jam.
# 3. Penurunan dari cuaca cerah ke hujan ringan mencapai sekitar 63%, menunjukkan pengaruh yang kuat.
# 4. Kategori cuaca ekstrem (weathersit=4) hanya muncul pada hour.csv, itu pun hanya 3 dari 17.379 baris data, sehingga tidak cukup representatif untuk dijadikan kesimpulan yang kuat.
#
# - Pertanyaan 2: Pengaruh musim terhadap penyewaan sepeda
# 1. Musim gugur (season=3) memiliki rata-rata penyewaan tertinggi: 5.644/hari dan 236/jam.
# 2. Musim semi (season=1) memiliki rata-rata penyewaan terendah: 2.604/hari dan 111/jam.
# 3. Selisih antara musim tertinggi dan terendah mencapai lebih dari 50%, menunjukkan musim berpengaruh signifikan.
# 4. Jumlah data di tiap musim relatif seimbang (sekitar 178-188 hari, atau 4.200-4.500 jam per musim), sehingga perbandingan ini valid dan bisa diandalkan.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
weather = df_day.groupby('weathersit')['cnt'].mean().reset_index()

plt.figure(figsize=(4,4))
sns.barplot(data=weather, x='weathersit', y='cnt')
plt.title('Rata-rata Penyewaan Sepeda Berdasarkan Kondisi Cuaca')
plt.xlabel('Kondisi Cuaca (1=Cerah, 2=Mendung, 3=Hujan Ringan)')
plt.ylabel('Rata-rata Jumlah Penyewaan')
plt.show()
print("\n")
plt.figure(figsize=(6,4))
sns.scatterplot(data=df_day, x='temp', y='cnt')
plt.title('Hubungan Suhu dengan Jumlah Penyewaan Sepeda')
plt.xlabel('Suhu (Normalisasi)')
plt.ylabel('Jumlah Penyewaan')
plt.show()

# %% [markdown]
# ### Pertanyaan 2:

# %%
season = df_day.groupby('season')['cnt'].mean().reset_index()

plt.figure(figsize=(4,4))
sns.barplot(data=season, x='season', y='cnt')
plt.title('Rata-rata Penyewaan Sepeda Berdasarkan Musim')
plt.xlabel('Musim (1=Musim Gugur, 2=Musim Semi, 3=Musim Panas, 4=Musim Dingin)')
plt.ylabel('Rata-rata Jumlah Penyewaan')
plt.show()
print("\n")
plt.figure(figsize=(6,4))
sns.scatterplot(data=df_day, x='hum', y='cnt')
plt.title('Hubungan Suhu dengan Jumlah Penyewaan Sepeda')
plt.xlabel('Suhu (Normalisasi)')
plt.ylabel('Jumlah Penyewaan')
plt.show()

# %% [markdown]
# **Insight:** (Opsional)
# - pertanyaan 1:
# Dari visualisasi bar chart terlihat bahwa batang tertinggi ada pada kategori cuaca cerah (weathersit=1), sedangkan batang terendah ada pada kategori hujan ringan (weathersit=3). Tinggi batang menurun secara konsisten dari cuaca 1 ke cuaca 3, yang menunjukkan bahwa kondisi cuaca yang semakin buruk berbanding lurus dengan penurunan jumlah penyewaan sepeda.
# - pertayaan 2:
# Dari visualisasi bar chart terlihat bahwa batang tertinggi ada pada musim gugur (season=3), diikuti musim panas (season=2) dan musim dingin (season=4) yang tingginya berdekatan, sedangkan batang terendah jauh terlihat pada musim semi (season=1). Perbedaan tinggi batang yang mencolok antara musim gugur dan musim semi menunjukkan bahwa musim memiliki pengaruh yang signifikan terhadap tingkat penyewaan sepeda.

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %%
df_day.groupby(['season', 'weathersit'])['cnt'].agg(['mean', 'count']).reset_index()
# Out:
#     season  weathersit         mean  count
# 0        1           1  2811.135135    111
# 1        1           2  2357.166667     66
# 2        1           3   934.750000      4
# 3        2           1  5548.548673    113
# 4        2           2  4236.705882     68
# 5        2           3  1169.000000      3
# 6        3           1  5878.257353    136
# 7        3           2  5222.479167     48
# 8        3           3  2751.750000      4
# 9        4           1  5043.563107    103
# 10       4           2  4654.000000     65
# 11       4           3  1961.600000     10

# %% [markdown]
# **Insight:** (Opsional)
# 1. Kombinasi terbaik: Musim Gugur + Cuaca Cerah, rata-rata 5.878 (tertinggi dari semua kombinasi)
# 2. Kombinasi terburuk: Musim Semi + Cuaca Hujan, rata-rata 935 (terendah), tapi datanya cuma 4 hari, jadi kurang kuat untuk disimpulkan
# 3. Pola menariknya: efek cuaca buruk itu konsisten menurunkan penyewaan di semua musim.

# %% [markdown]
# ## Conclusion & Recommendation

# %% [markdown]
# - **Conclusion pertanyaan 1:** Berdasarkan output di atas, dapat disimpulkan bahwa kondisi cuaca memengaruhi jumlah penyewaan sepeda. Hal ini terlihat dari pola yang konsisten, baik pada data harian day.csv maupun data per jam hour.csv, di mana semakin buruk kondisi cuaca, rata-rata jumlah penyewaan sepeda semakin menurun. Namun, pada hour.csv, kategori cuaca 4 ekstrem hanya muncul sebanyak 3 kali dari total data, sehingga jumlah data tersebut belum cukup representatif untuk dijadikan kesimpulan yang kuat.
# - **Conclusion pertanyaan 2:** Musim gugur season 3 memiliki jumlah penyewaan sepeda tertinggi, sedangkan musim semi season 1 memiliki jumlah penyewaan terendah. Musim memiliki pengaruh signifikan terhadap tingkat penyewaan sepeda, dengan selisih rata-rata lebih dari 50% antara musim tertinggi dan terendah, dan pola ini konsisten baik pada data harian maupun data per jam.

# %% [markdown]
# **Rekomendasi Action Item:**
# 1. Untuk ketersediaan sepeda
# Kurangi jumlah sepeda yang dioperasikan saat cuaca buruk diprediksi terutama kategori 3: hujan/salju ringan, karena permintaan turun. Sepeda bisa dialihkan untuk maintenance rutin di hari-hari seperti ini.
# 2. Siapkan maksimal di musim gugur, karena ini musim dengan permintaan tertinggi pastikan stok sepeda cukup dan station tidak kehabisan unit di jam-jam sibuk.
# Kurangi kapasitas di musim semi, karena permintaan terendah (kurang dari setengah musim gugur) bisa jadi waktu yang pas untuk perbaikan atau upgrade fasilitas stasiun.
# 3. Beri promo/diskon saat cuaca mendung atau berpotensi hujan ringan (bukan hujan lebat) untuk memberi dorongan agar orang tetap menyewa meski cuaca kurang ideal potensi menaikkan penyewaan yang biasanya turun di kondisi ini.
